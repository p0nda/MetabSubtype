# %%
import pandas as pd
import numpy as np

# %%
sample_id_df=pd.read_csv('../data/sample_hospital_id.csv',index_col=0)
sample_df=pd.read_csv('../data/Using/sample.csv',index_col=0)

# %%
blood_sample_df=pd.merge(sample_df,sample_id_df,left_on='hospital_id',right_on="住院号")
blood_sample_df
# blood_sample_df.to_csv("sample_info_with_blood.csv")
# Out:
#     Unnamed: 0  hospital_id Name  batch         os  oss type  TMN 主要分型 次要分型  \
# 0         19.0       640948  王谋年    1.0  14.770000  1.0    P  III    A  NaN
# 1         30.0       605031  王文桂    1.0   0.730000  1.0    N    I    N   AY
# 2         31.0       636720  庄海良    1.0  39.670000  0.0    P    I    A  NaN
# 3         32.0       637067  沈君明    1.0  32.070000  0.0    N    I    N  NaN
# 4         33.0       639254   王文    1.0  38.800000  0.0    P   II    N  NaN
# 5         34.0       643466  张德义    1.0  35.970000  0.0    P   II    V  NaN
# 6         35.0       649485  谷良同    1.0   9.200000  1.0    N    I    A  NaN
# 7         37.0      2034261  黄巧华    1.0  17.170000  1.0    N    I    A  NaN
# 8         46.0       649081  吴桂平    1.0  29.100000  0.0    N   II    0  NaN
# 9         46.0       649081  吴桂平    1.0  29.100000  0.0    N   II    0  NaN
# 10        46.0       649081  吴桂平    1.0  29.100000  0.0    N   II    0  NaN
# ...
